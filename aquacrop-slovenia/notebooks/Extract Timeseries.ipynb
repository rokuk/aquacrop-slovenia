# %% [markdown]
# # Extract Timeseries
#
# This code will read climate projections from NetCDF files and extract data for one point (timeseries for each model/scenario).
#
# Source NetCDF files with historical, rcp26, rcp45 and rcp85 scenarios are in the data/climate folder. They were downloaded from [OPSI](https://podatki.gov.si/data/)

# %%
# %load_ext autoreload
# %autoreload 2
