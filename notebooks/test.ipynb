# %%
import pandas as pd

from aquacrop_slovenia import config

# %%
df = pd.read_pickle(config.PROCESSED_DIR / "yield" / "maize.pkl")

# %%
df
# Out:
#      location  year management fertilization product     yield
# 0      jablje  1993          A            N0   grain  6.163000
# 1      jablje  1994          A            N0   grain  5.558000
# 2      jablje  1995          A            N0   grain  6.702000
# 3      jablje  1996          A            N0   grain  2.884000
# 4      jablje  1997          A            N0   grain  4.139000
# ...       ...   ...        ...           ...     ...       ...
# 2375  rakican  2022          B            N3      hi  0.320446
# 2376  rakican  2022          C            N0      hi  0.344657
# 2377  rakican  2022          C            N1      hi  0.359623
# 2378  rakican  2022          C            N2      hi  0.305224
# 2379  rakican  2022          C            N3      hi  0.331307
#
# [2380 rows x 6 columns]

# %%
get_yield
