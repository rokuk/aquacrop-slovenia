# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import os

from aquacrop_slovenia import config

# %%
temp = pd.read_csv(config.RAW_WEATHER_DIR / "station_9_temperature.csv", sep=";")
precip = pd.read_csv(config.RAW_WEATHER_DIR / "station_9_precipitation.csv", sep=";")
et = pd.read_csv(config.RAW_WEATHER_DIR / "station_9_evapotranspiration.csv", sep=";")

# %%
temp["datum"] = pd.to_datetime(temp.datum, format="%m.%d.%Y")
precip["datum"] = pd.to_datetime(precip.datum, format="%m.%d.%Y")
et["datum"] = pd.to_datetime(et.datum, format="%m.%d.%Y")
# Out:
# C:\Users\rokku\AppData\Local\Temp\ipykernel_42324\3531301229.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   temp["datum"] = pd.to_datetime(temp.datum, format="%m.%d.%Y")
# C:\Users\rokku\AppData\Local\Temp\ipykernel_42324\3531301229.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   precip["datum"] = pd.to_datetime(precip.datum, format="%m.%d.%Y")
# C:\Users\rokku\AppData\Local\Temp\ipykernel_42324\3531301229.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   et["datum"] = pd.to_datetime(et.datum, format="%m.%d.%Y")

# %%
temp
# Out:
#        postaja      datum  tpov  tmin  tmax
# 0            8 1993-01-01  -7.0 -12.0  -1.0
# 1            8 1993-01-02  -8.6 -14.5  -4.2
# 2            8 1993-01-03  -6.1  -9.2  -3.1
# 3            8 1993-01-04  -7.2  -9.7  -3.3
# 4            8 1993-01-05  -8.7 -13.2  -2.5
# ...        ...        ...   ...   ...   ...
# 11317        8 2023-12-27   5.1  -2.1  10.9
# 11318        8 2023-12-28   7.6   1.7  11.0
# 11319        8 2023-12-29   5.9  -1.7  11.5
# 11320        8 2023-12-30   4.0  -1.5  11.3
# 11321        8 2023-12-31   6.6  -1.1  10.0
#
# [11322 rows x 5 columns]

# %%
temp.describe()
# Out:
#        postaja                datum          tpov          tmin          tmax
# count  11322.0                11322  11322.000000  11322.000000  11322.000000
# mean       8.0  2008-07-01 12:00:00      9.556147      4.265775     15.616207
# min        8.0  1993-01-01 00:00:00    -17.100000    -23.700000     -9.100000
# 25%        8.0  2000-10-01 06:00:00      2.700000     -1.600000      8.100000
# 50%        8.0  2008-07-01 12:00:00     10.000000      4.700000     16.100000
# 75%        8.0  2016-03-31 18:00:00     16.500000     10.700000     23.300000
# max        8.0  2023-12-31 00:00:00     28.300000     20.800000     38.100000
# std        0.0                  NaN      8.273927      7.625235      9.417377

# %%
precip
# Out:
#        postaja      datum  pad
# 0            8 1993-01-01  0.0
# 1            8 1993-01-02  0.0
# 2            8 1993-01-03  0.0
# 3            8 1993-01-04  0.0
# 4            8 1993-01-05  0.0
# ...        ...        ...  ...
# 11317        8 2023-12-27  0.0
# 11318        8 2023-12-28  0.0
# 11319        8 2023-12-29  0.0
# 11320        8 2023-12-30  0.0
# 11321        8 2023-12-31  0.0
#
# [11322 rows x 3 columns]

# %%
precip.describe()
# Out:
#        postaja                datum           pad
# count  11322.0                11322  11322.000000
# mean       8.0  2008-07-01 12:00:00      3.660731
# min        8.0  1993-01-01 00:00:00      0.000000
# 25%        8.0  2000-10-01 06:00:00      0.000000
# 50%        8.0  2008-07-01 12:00:00      0.000000
# 75%        8.0  2016-03-31 18:00:00      1.900000
# max        8.0  2023-12-31 00:00:00    227.100000
# std        0.0                  NaN      9.488262

# %%
et
# Out:
#        postaja      datum  etp
# 0            8 1993-01-01  0.4
# 1            8 1993-01-02  0.6
# 2            8 1993-01-03  0.7
# 3            8 1993-01-04  0.3
# 4            8 1993-01-05  0.2
# ...        ...        ...  ...
# 11104        8 2023-12-27  5.8
# 11105        8 2023-12-28  5.8
# 11106        8 2023-12-29  5.8
# 11107        8 2023-12-30  5.8
# 11108        8 2023-12-31  4.8
#
# [11109 rows x 3 columns]

# %%
et.describe()
# Out:
#        postaja                          datum           etp
# count  11109.0                          11109  11107.000000
# mean       8.0  2008-04-30 21:58:24.725897984      1.984874
# min        8.0            1993-01-01 00:00:00      0.000000
# 25%        8.0            2000-08-09 00:00:00      0.600000
# 50%        8.0            2008-03-17 00:00:00      1.600000
# 75%        8.0            2015-10-24 00:00:00      3.100000
# max        8.0            2023-12-31 00:00:00      7.000000
# std        0.0                            NaN      1.585899

# %%
meteo_data = pd.merge(pd.merge(temp, precip, on="datum", how="outer"), et, on="datum", how="outer")
meteo_data.drop(["postaja_x", "postaja_y", "postaja"], axis=1, inplace=True)

# %%
meteo_data
# Out:
#            datum  tpov  tmin  tmax  pad  etp
# 0     1993-01-01  -7.0 -12.0  -1.0  0.0  0.4
# 1     1993-01-02  -8.6 -14.5  -4.2  0.0  0.6
# 2     1993-01-03  -6.1  -9.2  -3.1  0.0  0.7
# 3     1993-01-04  -7.2  -9.7  -3.3  0.0  0.3
# 4     1993-01-05  -8.7 -13.2  -2.5  0.0  0.2
# ...          ...   ...   ...   ...  ...  ...
# 11317 2023-12-27   5.1  -2.1  10.9  0.0  5.8
# 11318 2023-12-28   7.6   1.7  11.0  0.0  5.8
# 11319 2023-12-29   5.9  -1.7  11.5  0.0  5.8
# 11320 2023-12-30   4.0  -1.5  11.3  0.0  5.8
# 11321 2023-12-31   6.6  -1.1  10.0  0.0  4.8
#
# [11322 rows x 6 columns]

# %%
meteo_data.describe()
# Out:
#                      datum          tpov          tmin          tmax  \
# count                11322  11322.000000  11322.000000  11322.000000
# mean   2008-07-01 12:00:00      9.556147      4.265775     15.616207
# min    1993-01-01 00:00:00    -17.100000    -23.700000     -9.100000
# 25%    2000-10-01 06:00:00      2.700000     -1.600000      8.100000
# 50%    2008-07-01 12:00:00     10.000000      4.700000     16.100000
# 75%    2016-03-31 18:00:00     16.500000     10.700000     23.300000
# max    2023-12-31 00:00:00     28.300000     20.800000     38.100000
# std                    NaN      8.273927      7.625235      9.417377
#
#                 pad           etp
# count  11322.000000  11107.000000
# mean       3.660731      1.984874
# min        0.000000      0.000000
# 25%        0.000000      0.600000
# 50%        0.000000      1.600000
# 75%        1.900000      3.100000
# max      227.100000      7.000000
# std        9.488262      1.585899

# %% [markdown]
# ## Visualize data

# %%
meteo_data.plot(x="datum", y=["tmax", "tpov", "tmin"], linewidth=0.5)
# Out:
# <Axes: xlabel='datum'>

# %%
meteo_data.plot(x="datum", y=["tmax", "tpov", "tmin"], linewidth=0.5, xlim=("2019-04-20","2021-09-30"))
# Out:
# <Axes: xlabel='datum'>

# %%
meteo_data.plot(x="datum", y=["pad"], linewidth=0.5)
# Out:
# <Axes: xlabel='datum'>

# %%
meteo_data.plot(x="datum", y=["etp"], linewidth=0.5)
# Out:
# <Axes: xlabel='datum'>

# %%
meteo_data.plot(x="datum", y=["etp"], linewidth=0.5, xlim=("2019-04-20","2021-09-30"))
# Out:
# <Axes: xlabel='datum'>

# %% [markdown]
# ## Weather statistics

# %%
climate_data = meteo_data.copy()
climate_data.loc[:, "Year"] = climate_data["datum"].dt.year
climate_data.loc[:, "Month"] = climate_data["datum"].dt.month
climate_data.loc[:, "Day"] = climate_data["datum"].dt.day
yearly_mean = climate_data.groupby('Year').mean()
yearly_sum = climate_data.groupby('Year').sum(numeric_only=True)
daily_mean = climate_data.groupby(['Month', 'Day']).mean()
daily_sum = climate_data.groupby("Year").cumsum(numeric_only=True)
monthly_mean = climate_data.groupby(['Month']).mean()
## Monthly ETP climatology
_etp = meteo_data[meteo_data["datum"].dt.year.between(1993, 2020) & (meteo_data["datum"].dt.year != 2017)]
monthly_etp = (
    _etp.groupby([_etp["datum"].dt.year, _etp["datum"].dt.month])["etp"]
    .sum()
    .groupby(level=1)
    .mean()
)
monthly_etp.index.name = "Month"

# %%
monthly_etp
# Out:
# Month
# 1      24.429630
# 2      30.933333
# 3      51.025926
# 4      66.911111
# 5      92.722222
# 6     103.240741
# 7     112.388889
# 8      96.188889
# 9      58.407407
# 10     38.422222
# 11     22.962963
# 12     20.333333
# Name: etp, dtype: float64

# %%
monthly_etp.sum()
# Out:
# np.float64(717.9666666666667)

# %%
yearly_mean[["tmin", "tpov", "tmax", "pad", "etp"]]
# Out:
#           tmin       tpov       tmax       pad       etp
# Year
# 1993  3.412603   8.726849  14.800000  3.235342  2.111233
# 1994  4.718082   9.856164  15.933425  3.466849  2.004658
# 1995  3.626575   8.638904  14.603288  3.935068  1.884384
# 1996  3.401639   7.926503  13.158197  3.933880  1.737158
# 1997  3.583836   8.675890  14.750959  3.134521  1.943288
# 1998  3.657260   8.939452  15.283836  3.692603  1.926301
# 1999  3.976164   8.898082  14.691781  3.809589  1.825753
# 2000  4.362568   9.957104  16.376776  3.932514  1.990164
# 2001  3.988493   9.277808  15.248219  3.205205  1.904384
# 2002  4.712603   9.756164  15.576438  3.224384  1.857808
# 2003  3.405205   9.454521  16.239726  2.769589  2.148485
# 2004  3.800546   8.703825  14.382514  4.402186  1.735519
# 2005  2.994247   8.400548  14.504658  4.152329  1.795342
# 2006  3.239178   9.098630  15.492877  3.014521  1.880000
# 2007  4.140548   9.965753  16.516164  3.439452  2.012055
# 2008  4.660383   9.672404  15.553279  4.321858  1.889344
# 2009  4.218082   9.643288  15.614521  3.921370  1.975616
# 2010  3.992877   8.855068  14.151781  4.325753  1.845479
# 2011  3.908493   9.611233  15.945205  2.704384  2.056712
# 2012  4.326776   9.917760  16.244536  3.546175  2.045082
# 2013  4.850685   9.738630  15.300548  3.757808  1.924932
# 2014  5.994795  10.787671  16.406301  5.189041  1.893151
# 2015  4.648219  10.136164  16.471507  2.984932  2.030685
# 2016  4.599454   9.737978  15.827869  3.619126  1.928142
# 2017  4.046027   9.711233  16.035068  3.823562  1.995395
# 2018  5.632603  10.572329  16.407123  3.846027  2.369041
# 2019  5.176712  10.543288  16.727397  3.602740  2.129315
# 2020  4.567213  10.069126  16.333333  3.567760  2.240437
# 2021  4.048493   9.339726  15.390685  3.471507  2.056164
# 2022  4.987397  10.843562  17.331233  2.646575  2.224110
# 2023  5.561644  10.787397  16.807123  4.801370  2.178904

# %%
yearly_mean.plot(y=["tmin", "tpov", "tmax"])
yearly_mean.plot(y="pad")
yearly_mean.plot(y="etp")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# Yearly sums of precipitation and ET

# %%
yearly_sum.plot(y=["pad", "etp"])
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# Climatology (whole period)

# %%
daily_mean.plot(y=["tmin", "tpov", "tmax"])
# Out:
# <Axes: xlabel='Month,Day'>

# %%
daily_sum.plot(y=["pad", "etp"])
# Out:
# <Axes: >

# %%
monthly_mean
# Out:
#                               datum       tpov       tmin       tmax  \
# Month
# 1     2008-01-16 09:17:25.161290240  -0.989386  -4.931946   3.567742
# 2     2008-02-15 00:00:00.000000000   0.524229  -4.347200   6.563086
# 3     2008-03-15 14:42:34.838709760   4.578044  -1.342456  11.482102
# 4     2008-04-15 02:42:34.838709760   9.427742   2.988602  16.212366
# 5     2008-05-15 14:42:34.838709504  14.342456   7.695838  20.984079
# 6     2008-06-15 02:42:34.838709504  18.595161  11.923333  25.044301
# 7     2008-07-15 14:42:34.838709760  19.905203  13.237669  26.942456
# 8     2008-08-15 14:42:34.838709504  19.235276  13.162435  26.430177
# 9     2008-09-15 02:42:34.838709504  14.237204   9.082043  20.994731
# 10    2008-10-15 14:42:34.838709760   9.753382   5.315713  15.897086
# 11    2008-11-15 02:42:34.838709760   4.716237   1.322258   9.052151
# 12    2008-12-15 14:42:34.838709760  -0.177732  -3.421540   3.699168
#
#             pad       etp    Year     Day
# Month
# 1      2.174818  1.185806  2008.0  16.000
# 2      2.656114  1.389965  2008.0  14.616
# 3      2.444641  1.759462  2008.0  16.000
# 4      2.962688  2.144778  2008.0  15.500
# 5      3.544745  2.758817  2008.0  16.000
# 6      4.137419  3.132851  2008.0  15.500
# 7      3.988762  3.296774  2008.0  16.000
# 8      4.520708  2.786785  2008.0  16.000
# 9      5.172688  1.873548  2008.0  15.500
# 10     4.085432  1.367846  2008.0  16.000
# 11     4.602796  1.032400  2008.0  15.500
# 12     3.620083  1.103226  2008.0  16.000

# %%
monthly_mean.plot(y=["tpov", "tmin", "tmax"])
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_mean.plot(y=["pad", "etp"], kind="bar")
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ## Missing data

# %%
for variable_name in ["tmin", "tpov", "tmax", "pad", "etp"]:
    print(variable_name)
    print(meteo_data[meteo_data[variable_name].isnull()])
# Out:
# tmin
# Empty DataFrame
# Columns: [datum, tpov, tmin, tmax, pad, etp]
# Index: []
# tpov
# Empty DataFrame
# Columns: [datum, tpov, tmin, tmax, pad, etp]
# Index: []
# tmax
# Empty DataFrame
# Columns: [datum, tpov, tmin, tmax, pad, etp]
# Index: []
# pad
# Empty DataFrame
# Columns: [datum, tpov, tmin, tmax, pad, etp]
# Index: []
# etp
#           datum  tpov  tmin  tmax  pad  etp
# 3818 2003-06-16  21.7  15.7  29.4  0.2  NaN
# 3830 2003-06-28  19.9  13.8  27.8  2.4  NaN
# 8766 2017-01-01  -5.7 -12.5   4.8  0.0  NaN
# 8767 2017-01-02  -0.6 -11.3   8.6  0.0  NaN
# 8768 2017-01-03  -3.0  -7.4   4.0  0.0  NaN
# ...         ...   ...   ...   ...  ...  ...
# 8974 2017-07-28  20.4  14.1  29.0  0.0  NaN
# 8975 2017-07-29  21.8  14.3  28.9  0.0  NaN
# 8976 2017-07-30  22.0  15.5  29.0  0.0  NaN
# 8977 2017-07-31  24.2  15.2  32.6  0.1  NaN
# 9070 2017-11-01   5.0  -3.2  13.4  0.0  NaN
#
# [215 rows x 6 columns]

# %%
meteo_data[meteo_data["etp"].isnull()]["datum"].tolist()
# Out:
# [Timestamp('2003-06-16 00:00:00'),
#  Timestamp('2003-06-28 00:00:00'),
#  Timestamp('2017-01-01 00:00:00'),
#  Timestamp('2017-01-02 00:00:00'),
#  Timestamp('2017-01-03 00:00:00'),
#  Timestamp('2017-01-04 00:00:00'),
#  Timestamp('2017-01-05 00:00:00'),
#  Timestamp('2017-01-06 00:00:00'),
#  Timestamp('2017-01-07 00:00:00'),
#  Timestamp('2017-01-08 00:00:00'),
#  Timestamp('2017-01-09 00:00:00'),
#  Timestamp('2017-01-10 00:00:00'),
#  Timestamp('2017-01-11 00:00:00'),
#  Timestamp('2017-01-12 00:00:00'),
#  Timestamp('2017-01-13 00:00:00'),
#  Timestamp('2017-01-14 00:00:00'),
#  Timestamp('2017-01-15 00:00:00'),
#  Timestamp('2017-01-16 00:00:00'),
#  Timestamp('2017-01-17 00:00:00'),
#  Timestamp('2017-01-18 00:00:00'),
#  Timestamp('2017-01-19 00:00:00'),
#  Timestamp('2017-01-20 00:00:00'),
#  Timestamp('2017-01-21 00:00:00'),
#  Timestamp('2017-01-22 00:00:00'),
#  Timestamp('2017-01-23 00:00:00'),
#  Timestamp('2017-01-24 00:00:00'),
#  Timestamp('2017-01-25 00:00:00'),
#  Timestamp('2017-01-26 00:00:00'),
#  Timestamp('2017-01-27 00:00:00'),
#  Timestamp('2017-01-28 00:00:00'),
#  Timestamp('2017-01-29 00:00:00'),
#  Timestamp('2017-01-30 00:00:00'),
#  Timestamp('2017-01-31 00:00:00'),
#  Timestamp('2017-02-01 00:00:00'),
#  Timestamp('2017-02-02 00:00:00'),
#  Timestamp('2017-02-03 00:00:00'),
#  Timestamp('2017-02-04 00:00:00'),
#  Timestamp('2017-06-17 00:00:00'),
#  Timestamp('2017-06-18 00:00:00'),
#  Timestamp('2017-06-19 00:00:00'),
#  Timestamp('2017-06-20 00:00:00'),
#  Timestamp('2017-06-21 00:00:00'),
#  Timestamp('2017-06-22 00:00:00'),
#  Timestamp('2017-06-23 00:00:00'),
#  Timestamp('2017-06-24 00:00:00'),
#  Timestamp('2017-06-25 00:00:00'),
#  Timestamp('2017-06-26 00:00:00'),
#  Timestamp('2017-06-27 00:00:00'),
#  Timestamp('2017-06-28 00:00:00'),
#  Timestamp('2017-06-29 00:00:00'),
#  Timestamp('2017-06-30 00:00:00'),
#  Timestamp('2017-07-01 00:00:00'),
#  Timestamp('2017-07-02 00:00:00'),
#  Timestamp('2017-07-03 00:00:00'),
#  Timestamp('2017-07-04 00:00:00'),
#  Timestamp('2017-07-05 00:00:00'),
#  Timestamp('2017-07-06 00:00:00'),
#  Timestamp('2017-07-07 00:00:00'),
#  Timestamp('2017-07-08 00:00:00'),
#  Timestamp('2017-07-09 00:00:00'),
#  Timestamp('2017-07-10 00:00:00'),
#  Timestamp('2017-07-11 00:00:00'),
#  Timestamp('2017-07-12 00:00:00'),
#  Timestamp('2017-07-13 00:00:00'),
#  Timestamp('2017-07-14 00:00:00'),
#  Timestamp('2017-07-15 00:00:00'),
#  Timestamp('2017-07-16 00:00:00'),
#  Timestamp('2017-07-17 00:00:00'),
#  Timestamp('2017-07-18 00:00:00'),
#  Timestamp('2017-07-19 00:00:00'),
#  Timestamp('2017-07-20 00:00:00'),
#  Timestamp('2017-07-21 00:00:00'),
#  Timestamp('2017-07-22 00:00:00'),
#  Timestamp('2017-07-23 00:00:00'),
#  Timestamp('2017-07-24 00:00:00'),
#  Timestamp('2017-07-25 00:00:00'),
#  Timestamp('2017-07-26 00:00:00'),
#  Timestamp('2017-07-27 00:00:00'),
#  Timestamp('2017-07-28 00:00:00'),
#  Timestamp('2017-07-29 00:00:00'),
#  Timestamp('2017-07-30 00:00:00'),
#  Timestamp('2017-07-31 00:00:00'),
#  Timestamp('2017-11-01 00:00:00')]

# %% [markdown]
# ## Infill missing data

# %% [markdown]
# We set all missing ET to 0

# %%
meteo_data.loc[meteo_data["etp"].isnull(), "etp"] = 0

# %% [markdown]
# ## Monthly ETP climatology

# %%
_etp = meteo_data[meteo_data["datum"].dt.year.between(1993, 2020) & (meteo_data["datum"].dt.year != 2017)]
monthly_etp = (
    _etp.groupby([_etp["datum"].dt.year, _etp["datum"].dt.month])["etp"]
    .sum()
    .groupby(level=1)
    .mean()
)
monthly_etp.index.name = "Month"
monthly_etp
# Out:
# Month
# 1      24.429630
# 2      30.933333
# 3      51.025926
# 4      66.911111
# 5      92.722222
# 6     103.240741
# 7     112.388889
# 8      96.188889
# 9      58.407407
# 10     38.422222
# 11     22.962963
# 12     20.333333
# Name: etp, dtype: float64

# %% [markdown]
# ## Export infilled data

# %%
pd.to_pickle(meteo_data, config.PROCESSED_WEATHER_DIR / "station_9.pkl")
