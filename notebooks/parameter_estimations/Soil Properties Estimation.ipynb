# %%
import pandas as pd
import numpy as np
from rosetta import rosetta

# %% [markdown]
# ## Jablje

# %%
clay = 16.77
silt = 13.43 + 17.47 + 24.63
sand = 23.22 + 3.98 + 0.51
print(sand, silt, clay)

bulk_density = 1.55
# Out:
# 27.71 55.53 16.77

# %%
sand + silt + clay
# Out:
# 100.01

# %%
data = [
    [sand, silt, clay, bulk_density]
]

# %%
#model_code = 2 # use sand, silt, clay
model_code = 3 # use sand, silt, clay, bulk_density
mean, stdev, codes = rosetta(3, data)

# %%
result = pd.DataFrame(np.vstack([mean, stdev]), columns=["theta_r", "theta_s", "alpha", "n", "Ksat", "K0", "Ipar"], index=["mean", "stdev"])

# %%
print(result)
# Out:
#         theta_r   theta_s     alpha         n       Ksat        K0      Ipar
# mean   0.077357  0.368969  0.005920  1.434695  10.040768  1.364022 -0.270382
# stdev  0.010149  0.009563  0.001095  0.053966   2.087633  0.714240  1.218423

# %% [markdown]
# ## Rakičan

# %%
clay = 14.67
silt = 5.68 + 7.8 + 17.72
sand = 38.11 + 15.31 + 0.62
print(sand, silt, clay)

bulk_density = 1.61
# Out:
# 54.04 31.2 14.67

# %%
sand + silt + clay
# Out:
# 99.91

# %%
data = [
    [sand, silt, clay, bulk_density]
]

# %%
#model_code = 2 # use sand, silt, clay
model_code = 3 # use sand, silt, clay, bulk_density
mean, stdev, codes = rosetta(3, data)

# %%
result = pd.DataFrame(np.vstack([mean, stdev]), columns=["theta_r", "theta_s", "alpha", "n", "Ksat", "K0", "Ipar"], index=["mean", "stdev"])

# %%
print(result)
# Out:
#         theta_r   theta_s     alpha         n       Ksat        K0      Ipar
# mean   0.071330  0.352487  0.012692  1.381476  13.508197  3.583156 -0.908597
# stdev  0.008851  0.008758  0.002151  0.036435   2.911376  2.021099  1.045974
