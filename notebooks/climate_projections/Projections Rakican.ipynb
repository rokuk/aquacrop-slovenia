# %%
# %load_ext autoreload
# %autoreload 2

# %%
from matplotlib import pyplot as plt
import pickle
import numpy as np

from aquacrop_slovenia.yield_projections import run_all_projections, get_model_scenario_combinations, \
    compute_period_statistics
from aquacrop_slovenia import config
# Out:
# Loaded data sizes: Temperatures=1096, ETo=1096, Rain=1096

# %%
LOCATION = "rakican"

# %%
# takes about a minute on 28 cores
projections = run_all_projections(LOCATION)
pickle.dump(projections, open(config.RESULTS_DIR / f"projections_v1_{LOCATION}.pkl", "wb"))
# Out:
# Setting up working directory at: E:\aquacrop\proj_rakican_model1_rcp45
# Setting up working directory at: E:\aquacrop\proj_rakican_model1_rcp85
# Setting up working directory at: E:\aquacrop\proj_rakican_model2_rcp85
# Setting up working directory at: E:\aquacrop\proj_rakican_model2_rcp45
# Setting up working directory at: E:\aquacrop\proj_rakican_model2_rcp26
# Setting up working directory at: E:\aquacrop\proj_rakican_model3_rcp85
# Setting up working directory at: E:\aquacrop\proj_rakican_model3_rcp45
# Setting up working directory at: E:\aquacrop\proj_rakican_model4_rcp26
# Setting up working directory at: E:\aquacrop\proj_rakican_model4_rcp45
# Setting up working directory at: E:\aquacrop\proj_rakican_model4_rcp85
# Setting up working directory at: E:\aquacrop\proj_rakican_model5_rcp45
# Setting up working directory at: E:\aquacrop\proj_rakican_model5_rcp85
# Setting up working directory at: E:\aquacrop\proj_rakican_model6_rcp45
# Setting up working directory at: E:\aquacrop\proj_rakican_model6_rcp85
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model1_rcp45\LIST\PROJECT.PRMRunning AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model2_rcp45\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model4_rcp85\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model3_rcp45\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
#
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model2_rcp85\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model3_rcp85\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model6_rcp45\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model2_rcp26\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model4_rcp26\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model1_rcp85\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model4_rcp45\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model6_rcp85\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model5_rcp85\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Running AquaCrop simulation with project file: E:\aquacrop\proj_rakican_model5_rcp45\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model6_rcp45\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model1_rcp45\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model3_rcp45\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model2_rcp85\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model4_rcp85\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model5_rcp45\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model2_rcp26\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model5_rcp85\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model4_rcp45\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model2_rcp45\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model6_rcp85\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model1_rcp85\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model4_rcp26\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\proj_rakican_model3_rcp85\aquacrop.exe
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model4 rcp85
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model4 rcp45
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model6 rcp45
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model2 rcp26
# AquaCrop simulation completed successfully
# Parsing simulation results...
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Results successfully parsed
# Completed rakican model6 rcp85
# Completed rakican model2 rcp85
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model3 rcp45
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model1 rcp45
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model5 rcp85
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model2 rcp45
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model4 rcp26
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model5 rcp45
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model1 rcp85
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed
# Completed rakican model3 rcp85

# %%
for model, scenario in get_model_scenario_combinations(LOCATION):
    plt.plot(projections[(model, scenario)].loc[:, "Y(dry)"])

# %%
projections[("model1", "rcp45")]
# Out:
#      Year1  Y(dry)
# 0     1981   1.865
# 1     1982   9.703
# 2     1983  10.297
# 3     1984   0.997
# 4     1985   6.470
# ..     ...     ...
# 115   2096  11.983
# 116   2097   8.403
# 117   2098  10.705
# 118   2099   9.463
# 119   2100   8.590
#
# [120 rows x 2 columns]

# %%
for model, scenario in get_model_scenario_combinations(LOCATION):
    print(f"{model}, {scenario}")
    print(compute_period_statistics(projections[(model, scenario)]))
    print()
# Out:
# model1, rcp45
#                Mean       Std    Min  Median     Max
# Period
# 1981-2010  6.796733  3.932019  0.585  7.0095  12.075
# 2011-2040  8.683500  3.204827  0.000  9.2960  12.439
# 2041-2070  6.082067  4.005748  0.438  6.1845  11.532
# 2071-2100  8.575800  3.583921  0.978  9.9830  12.639
#
# model1, rcp85
#                Mean       Std    Min   Median     Max
# Period
# 1981-2010  6.984967  3.658944  0.574   6.8875  12.054
# 2011-2040  6.330133  3.764863  0.754   5.4855  11.914
# 2041-2070  8.668667  3.836578  0.585  10.5665  12.109
# 2071-2100  7.347133  3.174848  0.910   8.2050  10.995
#
# model2, rcp26
#                Mean       Std    Min  Median     Max
# Period
# 1981-2010  7
fig, axes = plt.subplots(1, len(scenarios), figsize=(6 * len(scenarios), 5), sharey=True)
if len(scenarios) == 1:
    axes = [axes]

for ax, scenario in zip(axes, scenarios):
    for i, model in enumerate(model_names):
        if (model, scenario) not in projections:
            continue
        result = projections[(model, scenario)]
        ax.plot(result["Year1"], result["Y(dry)"], color=colors[i % len(colors)], linewidth=0.9, alpha=0.8, label=model)

    for year in period_boundaries:
        ax.axvline(year - 0.5, color="black", linewidth=0.6, linestyle="--", alpha=0.4)

    ax.set_title(scenario)
    ax.set_xlabel("Year")
    ax.legend(fontsize=8)

axes[0].set_ylabel("Dry yield (t ha⁻¹)")
fig.suptitle(f"AquaCrop yield projections — {LOCATION}", fontsize=13)
fig.tight_layout()
plt.show()

# %%
period_labels = list(PERIODS.keys())
n_periods = len(period_labels)
n_models = len(model_names)
group_width = 0.8
box_width = group_width / n_models

fig, axes = plt.subplots(1, len(scenarios), figsize=(7 * len(scenarios), 5), sharey=True)
if len(scenarios) == 1:
    axes = [axes]

for ax, scenario in zip(axes, scenarios):
    for i, model in enumerate(model_names):
        if (model, scenario) not in projections:
            continue
        result = projections[(model, scenario)]
        color = colors[i % len(colors)]
        positions, data = [], []
        for j, (label, (start, end)) in enumerate(PERIODS.items()):
            s = result.loc[(result["Year1"] >= start) & (result["Year1"] <= end), "Y(dry)"].values
            positions.append(j + (i - (n_models - 1) / 2) * box_width)
            data.append(s)

        bp = ax.boxplot(data, positions=positions, widths=box_width * 0.85,
                        patch_artist=True, manage_ticks=False)
        for patch in bp["boxes"]:
            patch.set_facecolor(color)
            patch.set_alpha(0.6)
        for key in ("whiskers", "caps", "fliers"):
            for line in bp[key]:
                line.set_color(color)
        for line in bp["medians"]:
            line.set_color("black")
        ax.plot([], [], color=color, linewidth=3, label=model)

    ax.set_xticks(range(n_periods))
    ax.set_xticklabels(period_labels, rotation=15)
    ax.set_title(scenario)
    ax.legend(fontsize=8)

axes[0].set_ylabel("Dry yield (t ha⁻¹)")
fig.suptitle(f"AquaCrop yield projections — {LOCATION} — 30-year period distributions", fontsize=13)
fig.tight_layout()
plt.show()

# %%
from aquacrop_slovenia.yield_projections import run_historical_simulation
from aquacrop_slovenia.reading_data import get_yield_for_comparison
from aquacrop_slovenia.plots import plot_yield_projections_boxplot_with_hist

hist_results = run_historical_simulation(LOCATION)
obs_yields = get_yield_for_comparison(LOCATION, product="grain", management="A", fertilization="N3")

fig = plot_yield_projections_boxplot_with_hist(projections, LOCATION, hist_results=hist_results, obs_yields=obs_yields)
plt.show()
# Out:
# Setting up working directory at: E:\aquacrop\hist_rakican
# Running AquaCrop simulation with project file: E:\aquacrop\hist_rakican\LIST\PROJECT.PRM
# Detected platform: windows (AMD64)
# Looking for executable at: C:\Users\rokku\Documents\Code\aquacrop-slovenia\.venv\Lib\site-packages\model\windows\aquacrop.exe
# Using AquaCrop executable: E:\aquacrop\hist_rakican\aquacrop.exe
# AquaCrop simulation completed successfully
# Parsing simulation results...
# Results successfully parsed

# %%
from aquacrop_slovenia.plots import plot_yield_projections_raincloud_with_hist

fig = plot_yield_projections_raincloud_with_hist(projections, LOCATION, hist_results=hist_results, obs_yields=obs_yields)
plt.show()

# %%
from aquacrop_slovenia.plots import add_reference_boxplots

period_colors = {"1981-2010": "steelblue", "2011-2040": "darkorange", "2041-2070": "seagreen", "2071-2100": "firebrick"}

fig, axes = plt.subplots(1, len(scenarios), figsize=(7 * len(scenarios), 5), sharey=True, sharex=True)
if len(scenarios) == 1:
    axes = [axes]

for ax, scenario in zip(axes, scenarios):
    for label, (start, end) in PERIODS.items():
        all_yields = []
        for model in model_names:
            if (model, scenario) not in projections:
                continue
            result = projections[(model, scenario)]
            s = result.loc[(result["Year1"] >= start) & (result["Year1"] <= end), "Y(dry)"].values
            all_yields.extend(s)
        if all_yields:
            ax.hist(all_yields, bins=20, density=True, alpha=0.45,
                    color=period_colors[label], label=label, edgecolor="white", linewidth=0.4)

    ax.set_title(scenario)
    ax.set_xlabel("Dry yield (t ha⁻¹)")

axes[0].set_ylabel("Density")

# Measured / historical reference, drawn as a horizontal boxplot strip above the histograms
y_top = axes[0].get_ylim()[1]
box_height = y_top * 0.12
for ax in axes:
    add_reference_boxplots(ax, y_top + box_height, hist_results, obs_yields,
                            box_width=box_height, box_gap=box_height * 0.3, vert=False)
    ax.legend(fontsize=8)
axes[0].set_ylim(top=y_top + 2.2 * box_height)

fig.suptitle(f"AquaCrop yield projections — {LOCATION} — 30-year period distributions", fontsize=13)
fig.tight_layout()
plt.show()

# %%
from aquacrop_slovenia.plots import plot_yield_projections_by_period

fig = plot_yield_projections_by_period(projections, LOCATION, hist_results=hist_results, obs_yields=obs_yields)
plt.show()

# %%
from aquacrop_slovenia.plots import plot_yield_projections_by_model

fig = plot_yield_projections_by_model(projections, LOCATION, hist_results=hist_results, obs_yields=obs_yields)
plt.show()

# %%
from aquacrop_slovenia.plots import plot_yield_projections_by_model_boxplot

fig = plot_yield_projections_by_model_boxplot(projections, LOCATION, hist_results=hist_results, obs_yields=obs_yields)
plt.show()

# %%
import pandas as pd
from matplotlib.patches import Patch

from aquacrop_slovenia.plots import add_reference_boxplots

scenario_colors = {"rcp26": "steelblue", "rcp45": "darkorange", "rcp85": "firebrick"}

fig, ax = plt.subplots(figsize=(12, 5))

for scenario in scenarios:
    frames = [
        projections[(model, scenario)].set_index("Year1")["Y(dry)"].rename(model)
        for model in model_names
        if (model, scenario) in projections
    ]
    ensemble = pd.concat(frames, axis=1)
    color = scenario_colors.get(scenario, "gray")

    ax.fill_between(ensemble.index, ensemble.min(axis=1), ensemble.max(axis=1),
                    alpha=0.08, color=color)
    ax.fill_between(ensemble.index, ensemble.quantile(0.25, axis=1), ensemble.quantile(0.75, axis=1),
                    alpha=0.2, color=color)
    ax.plot(ensemble.index, ensemble.median(axis=1), color=color, linewidth=2, label=scenario)

for year in period_boundaries:
    ax.axvline(year - 0.5, color="black", linewidth=0.6, linestyle="--", alpha=0.4)

# Measured / historical reference, as boxplots just before the projection timeline starts
first_year = ensemble.index.min()
ref_center = first_year - 6
add_reference_boxplots(ax, ref_center, hist_results, obs_yields, box_width=3)
ax.axvline(first_year - 2.5, color="gray", linewidth=0.8, linestyle="--", alpha=0.5)
ax.set_xlim(left=first_year - 10)

handles, labels = ax.get_legend_handles_labels()
handles += [
    Patch(facecolor="gray", alpha=0.35, label="IQR (25–75%)"),
    Patch(facecolor="gray", alpha=0.12, label="Min–Max"),
]
ax.legend(handles=handles, fontsize=8)

ax.set_xlabel("Year")
ax.set_ylabel("Dry yield (t ha⁻¹)")
ax.set_title(f"AquaCrop ensemble median — {LOCATION}")
fig.tight_layout()
plt.show()
